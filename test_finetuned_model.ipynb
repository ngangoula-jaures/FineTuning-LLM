# %% [markdown]
# <a href="https://colab.research.google.com/github/ngangoula-jaures/FineTuning-LLM/blob/main/test_finetuned_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers
# !pip install --upgrade torchao

# %%
# !pip install -U bitsandbytes>=0.46.1

# %%
# connexion à Hugging Face
from huggingface_hub import notebook_login
notebook_login()

# %%
# téléchargement du model et du tokenizer
from transformers import AutoModel, pipeline, AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

model_id = "JauresN16/llama-2-7b-custom-finetune"
model = AutoModelForCausalLM.from_pretrained("JauresN16/llama-2-7b-custom-finetune", dtype="auto")
#bnb_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_compute_dtype=torch.float16)
#model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/128 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/424 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.62M [00:00<?, ?B/s]

# %%
pipe = pipeline(
    task = "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    device=0
)

# Test
prompt = "What is backpropagation?"
result = pipe(prompt, max_new_tokens=50)

print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/128 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=4096) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer LlamaTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# What is backpropagation?
#  In a nutshell, it's a technique for learning the parameters of a neural network.
#
# More specifically, backpropagation is a method for training a neural network. It works by feeding a neural network with a set of
